# %%
from bs4 import BeautifulSoup
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import regex as re
from tqdm import tqdm
import pandas as pd
import time 
import pickle as pkl
from urllib3.exceptions import InsecureRequestWarning
import warnings

warnings.simplefilter(action='ignore', category=(FutureWarning, DeprecationWarning, InsecureRequestWarning))

# %%
def fix_base_prefix(url):
    prefix = 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/'
    if url.startswith(prefix):
        return url
    return prefix + url

def fix_index_prefix(url):
    prefix = 'https://web.archive.org/'
    if url.startswith(prefix):
        return url
    return prefix + url

def scrape_base(url):
    def filter(to_filter):
        pattern = re.compile(r'.*ExList\/[A-Za-z]+\#*[A-Za-z]+')

        if re.search(pattern, str(to_filter)):
            return True 
        return False
    
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    links = []
    for link in soup.find_all('a'):
        if filter(link):
            links.append(link.get('href'))

    return links

def mount_session():
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
        (KHTML, like Gecko) Ubuntu Chromium/80.0.3987.163 Chrome/80.0.3987.163 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9,es;q=0.8,pt;q=0.7'
    }

    session = requests.Session()
    retry = Retry(connect=3, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)

    return session, headers

def scrape_instance(url):
    def filter(to_filter):
        pattern = re.compile(r'.*WeightExercises\/[A-Za-z]+\/[A-Za-z]+')

        if re.search(pattern, str(to_filter)):
            return True 
        return False
    
    session, headers = mount_session()

    links = []
    try:
        page = session.get(url, headers=headers, verify=False)
        soup = BeautifulSoup(page.content, 'html.parser')

        for link in soup.find_all('a'):
            if filter(link):
                links.append(link.get('href'))
    except requests.exceptions.ConnectionError:
        time.sleep(5)
    
    return links

# %%
base_url = 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/Directory'

links = scrape_base(base_url)
standardized_links = [fix_base_prefix(link) for link in links]
# Out:
# ['https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/NeckWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/NeckWt#Sternocleidomastoid', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/NeckWt#Splenius', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ShouldWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ShouldWt#Anterior', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ShouldWt#Lateral', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ShouldWt#Posterior', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ShouldWt#Supraspinatus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ArmWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ArmWt#Triceps', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ArmWt#Biceps', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ArmWt#Brachialis', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt#Brachioradialis', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt#WristFlexors', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt#Extensors', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt#Pronators', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ForeArmWt#Supinators', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#General', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#Latissimus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#UpperTrap', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#MiddleTrap', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#Trapezius', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#UpperTrap', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#Rhomboids', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#Infraspinatus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/BackWt#Subscapularis', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt#General', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt#General', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt#Clavicular', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt#Pectoralis', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/ChestWt#Anterior', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt#Rectus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt#Transverse', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt#Obliques', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt#Quadratus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/WaistWt#Erector', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/HipsWt', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/HipsWt#Gluteus', 'https://web.archive.org/web/20230920212653/https://exrx.net/Lists/ExList/HipsWt#Abductors', 'https://web.archive.org/web/2 ...

# %%
total_indexes = []
with tqdm(total=len(links)) as pbar:
    for link in standardized_links:
        total_indexes.extend(scrape_instance(link))
        pbar.update(1)
total_indexes = list(set(total_indexes))
# Out:
# 100%|██████████| 55/55 [06:08<00:00,  6.71s/it]

# %%
standardized_indexes = [fix_index_prefix(link) for link in total_indexes]

# %%
pattern = r'https://exrx\.net/(.+)'
links = ['https://exrx.net/' + re.search(pattern, link).group(1) for link in standardized_indexes]

# %%
df = pd.DataFrame(columns=["exercise", "utility", "mechanics", "force", "target_muscles", "synergist_muscles", "stabilizer_muscles"])

def extract_muscles(soup, section_name):
    muscle_ul = soup.find("strong", text=section_name)
    muscles = []
    try:
        muscle_ul = muscle_ul.next_element.next_element
        for i in muscle_ul.find_all("li"):
            muscles.append(i.text)
    except (AttributeError, TypeError):
        muscles.append(muscle_ul.text if muscle_ul else '')
    return muscles

def extract_exercise(soup):
    try:
        exercise = soup.find("h1").text
    except AttributeError:
        exercise = ""
    return exercise

def extract_table(soup):
    try:
        table = soup.find_all("table")
    except AttributeError:
        table = ""
    return table

def scrape_info(link):
    session, headers = mount_session()

    try:
        page = session.get(link, headers=headers, verify=False)
        soup = BeautifulSoup(page.content, "html.parser")

        title = extract_exercise(soup)
        if title == "":
            return None

        table = extract_table(soup)

        classifications = []
        for row in table:
            row = row.find_all("tr")
            for td in row:
                td = td.find_all("td")
                for i in td:
                    classifications.append(i.text.replace(":", ""))

        if not classifications:
            classifications = ["", "", "", "", "", ""]

        target_muscles = extract_muscles(soup, "Target")
        synergist_muscles = extract_muscles(soup, "Synergists")
        stabilizer_muscles = extract_muscles(soup, "Stabilizers")
    except requests.exceptions.ConnectionError:
        time.sleep(3)

    data = {
        "exercise": title,
        "utility": classifications[1],
        "mechanics": classifications[3],
        "force": classifications[5],
        "target_muscles": target_muscles,
        "synergist_muscles": synergist_muscles,
        "stabilizer_muscles": stabilizer_muscles
    }

    return data

# %%
data_list = []
premium_list = []
with tqdm(total=len(standardized_indexes)) as pbar:
    for link in links:
        data = scrape_info(link)
        # Exercise is either behind a pay wall or does not exist
        if data is None or data['exercise'] == 'Premium Content':
            premium_list.append(link)
        else:
            data_list.append(data)
        pbar.update(1)
# Out:
# 100%|██████████| 1493/1493 [53:38<00:00,  2.16s/it]

# %%
df = pd.DataFrame(data_list)
df.to_csv("new_exrx.csv", index=False)
df.head(n=10)
pkl.dump(premium_list, open("premium_list.pkl", "wb"))
# Out:
#                             exercise  \
# 0     Lever Single Leg Split V-Squat
# 1         Lever Squat (plate loaded)
# 2          Side Bridge Hip Abduction
# 3                 Sled One Hand Grip
# 4        Barbell Decline Bench Press
# 5           Dumbbell Lateral Step-up
# 6           Weighted Twisting Crunch
# 7     Lever Lying Rear Lateral Raise
# 8  Cable Bent-over Triceps Extension
# 9                   Cable Rear Lunge
#
#                                         utility          mechanics force  \
# 0           AuxiliaryMechanicsCompoundForcePush  CompoundForcePush  Push
# 1               BasicMechanicsCompoundForcePush  CompoundForcePush  Push
# 2           AuxiliaryMechanicsIsolatedForcePush  IsolatedForcePush  Push
# 3  Basic or AuxiliaryMechanicsIsolatedForcePull  IsolatedForcePull  Pull
# 4  Basic or AuxiliaryMechanicsCompoundForcePush  CompoundForcePush  Push
# 5           AuxiliaryMechanicsCompoundForcePush  CompoundForcePush  Push
# 6           AuxiliaryMechanicsIsolatedForcePull  IsolatedForcePull  Pull
# 7           AuxiliaryMechanicsIsolatedForcePull  IsolatedForcePull  Pull
# 8  Basic or AuxiliaryMechanicsIsolatedForcePush  IsolatedForcePush  Push
# 9           AuxiliaryMechanicsCompoundForcePush  CompoundForcePush  Push
#
#                                       target_muscles  \
# 0                                  [Gluteus Maximus]
# 1                                       [Quadriceps]
# 2  [Tensor Fasciae LataeGluteus MediusGluteus Min...
# 3                                    [Wrist Flexors]
# 4                        [Pectoralis Major, Sternal]
# 5                                       [Quadriceps]
# 6                                         [Obliques]
# 7                               [Deltoid, Posterior]
# 8                                  [Triceps Brachii]
# 9                                       [Quadriceps]
#
#                                    synergist_muscles  \
# 0  [QuadricepsAdductor MagnusSoleus, Adductor Mag...
# 1  [Gluteus MaximusAdductor MagnusSoleus, Adducto...
# 2  [ObliquesQuadratus lumborumPsoas majorIliocast...
# 3                                             [None]
# 4  [Pectoralis Major, ClavicularDeltoid, Anterior...
# 5  [Gluteus MaximusAdductor MagnusSoleusGastrocne...
# 6         [Rectus AbdominisPsoas major, Psoas major]
# 7  [InfraspinatusTeres MinorTrapezius, MiddleTrap...
# 8                                             [None]
# 9  [Gluteus MaximusAdductor MagnusSoleus, Adducto...
#
#                                   stabilizer_muscles
# 0  [Gluteus MediusGluteus MinimusQuadratus Lumbor...
# 1  [Erector SpinaeTrapezius, UpperTrapezius, Midd...
# 2  [Latissimus dorsiPectoralis minorLevator Scapu...
# 3                       [No significant stabilizers]
# 4                                                 []
# 5  [Erector SpinaeGluteus MediusGluteus MinimusQu...
# 6                       [No significant stabilizers]
# 7                       [No significant stabilizers]
# 8  [Deltoid, AnteriorPectoralis Major, Clavicular...
# 9  [Erector SpinaeTrapezius, UpperTrapezius, Lowe...
